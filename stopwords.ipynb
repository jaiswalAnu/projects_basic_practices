# %%
import spacy

from spacy.lang.en.stop_words import STOP_WORDS

len(STOP_WORDS)
# Out:
# 326

# %%
nlp = spacy.load("en_core_web_sm")

doc = nlp("We just opened our wings, the flying part is coming soon")

for token in doc:
    if token.is_stop:
        print(token)
# Out:
# We
# just
# our
# the
# part
# is

# %%
def preprocess(text):
    doc = nlp(text)
    
    no_stop_words = [token.text for token in doc if not token.is_stop]
    return " ".join(no_stop_words)

# %%
preprocess("Musk wants time to prepare for a trial over his")
# Out:
# 'Musk wants time prepare trial'

# %%
preprocess("The other is not other but your divine brother")
# Out:
# 'divine brother'

# %%
import pandas as pd

df = pd.read_json("doj_press.json",lines=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-f587f00a37f5> in <cell line: 3>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_json("doj_press.json",lines=True)
#       4
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df.head(5)

# %%
df = df[df["topics"].str.len() != 0]
df.head()

# %%
df.shape

# %%
df =df.head(100)
df.shape

# %%
df["contents_new"] = df.contents.apply(preprocess)

# %%
df

# %%
len(df.contents[4])

# %%
df.contents[4][:300]

# %%
df.contents_new[4][:300]

# %% [markdown]
# ## (1) Sentiment detection: Not always but in some cases, based on your dataset it can change the sentiment of a sentence if you remove stop words

# %%
preprocess("this is a good movie")

# %%
preprocess("this is not a good movie")

# %% [markdown]
# (2) Language translation: Say you want to translate following sentence from english to telugu. Before actual translation if you remove stop words and then translate, it will produce horrible **result** italicized text

# %%
preprocess("how are you doing dhaval?")

# %% [markdown]
# ## (3) Chat bot or any Q&A system

# %%
preprocess("I don't find yoga mat on your website. Can you help?")
